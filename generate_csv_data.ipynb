# %%
import pandas as pd

# %%
df = pd.read_csv("books_data.csv", sep=',', error_bad_lines=False, quoting=3, engine='python')
df
# Out:
# /var/folders/tt/2j1c33w92454ry7jrc020t2h0000gn/T/ipykernel_48510/3157583570.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("books_data.csv", sep=',', error_bad_lines=False, quoting=3, engine='python')
# Skipping line 3350: Expected 12 fields in line 3350, saw 13
# Skipping line 4704: Expected 12 fields in line 4704, saw 13
# Skipping line 5879: Expected 12 fields in line 5879, saw 13
# Skipping line 8981: Expected 12 fields in line 8981, saw 13
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...

# %%
books = df.query("authors.str.contains('/') == False and authors.str.len() < 15 and title.str.len() < 25").sample(15)
books
# Out:
#        bookID                     title         authors  average_rating  \
# 8049    30934            Black Mischief    Evelyn Waugh            3.76
# 2345     8545               Wild Horses    Dick Francis            3.91
# 8103    31122      I Capture the Castle     Dodie Smith            4.00
# 8717    33563        Under the Red Flag          Ha Jin            3.88
# 6822    25709  Summa Theologica  5 Vols  Thomas Aquinas            4.12
# 3444    12561              The Guardian   Jane Hamilton            3.72
# 4182    14964              Body Surfing    Anita Shreve            3.32
# 2889    10711                 God Knows   Joseph Heller            3.80
# 4567    16429               The Husband     Dean Koontz            3.80
# 1677     5848        The Middle Passage    V.S. Naipaul            3.61
# 8044    30892                  The Main       Trevanian            3.86
# 1240     4273               About a Boy     Nick Hornby            3.80
# ...

# %%
books = books.loc[:, ['bookID', 'title', 'authors'] ]
books
# Out:
#        bookID                     title         authors
# 8049    30934            Black Mischief    Evelyn Waugh
# 2345     8545               Wild Horses    Dick Francis
# 8103    31122      I Capture the Castle     Dodie Smith
# 8717    33563        Under the Red Flag          Ha Jin
# 6822    25709  Summa Theologica  5 Vols  Thomas Aquinas
# 3444    12561              The Guardian   Jane Hamilton
# 4182    14964              Body Surfing    Anita Shreve
# 2889    10711                 God Knows   Joseph Heller
# 4567    16429               The Husband     Dean Koontz
# 1677     5848        The Middle Passage    V.S. Naipaul
# 8044    30892                  The Main       Trevanian
# 1240     4273               About a Boy     Nick Hornby
# 10483   42692                   Mila 18       Leon Uris
# 3285    12045        An Unofficial Rose    Iris Murdoch
# 10904   44597         Wide Sargasso Sea       Jean Rhys

# %%
import random

n = 15
numCopies = [random.randint(0,4) for _ in range(n)]
numCopies
# Out:
# [3, 2, 2, 0, 1, 2, 0, 4, 2, 3, 1, 4, 2, 1, 3]

# %%
books.insert(3, "num_copies", numCopies)
books
# Out:
#        bookID                     title         authors  num_copies
# 8049    30934            Black Mischief    Evelyn Waugh           3
# 2345     8545               Wild Horses    Dick Francis           2
# 8103    31122      I Capture the Castle     Dodie Smith           2
# 8717    33563        Under the Red Flag          Ha Jin           0
# 6822    25709  Summa Theologica  5 Vols  Thomas Aquinas           1
# 3444    12561              The Guardian   Jane Hamilton           2
# 4182    14964              Body Surfing    Anita Shreve           0
# 2889    10711                 God Knows   Joseph Heller           4
# 4567    16429               The Husband     Dean Koontz           2
# 1677     5848        The Middle Passage    V.S. Naipaul           3
# 8044    30892                  The Main       Trevanian           1
# 1240     4273               About a Boy     Nick Hornby           4
# 10483   42692                   Mila 18       Leon Uris           2
# ...

# %%
books = books.rename(columns={'bookID':'book_id'})

# %%
books.to_csv("library.csv", index=False)
